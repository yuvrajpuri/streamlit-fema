# %% [markdown]
# ### System Setup

# %%
# Libraries

import json
import os
import re
from PIL import Image, ImageDraw

# %%
# Variables

# Base directory
source_base_dir = "../yuvi"  # Base directory for source data

# JSON file name
json_file_name = "_annotations.coco.json"

# %% [markdown]
# ### Prepare Data

# %%
# Function to process a single directory
def process_directory(source_dir):
    json_path = os.path.join(source_dir, json_file_name)
    output_json_path = json_path  # Save the updated JSON in the same directory

    # Read the original COCO JSON file
    with open(json_path, "r") as f:
        coco_data = json.load(f)

    # Get list of images in the source directory (long names)
    image_files = {img for img in os.listdir(source_dir) if img.lower().endswith(('.jpg', '.jpeg', '.png'))}

    # Create a mapping dictionary long names -> short names
    name_mapping = {}

    for img_name in image_files:
        # Extract the main identifier from the short name (example: "image_00003")
        base_name_match = re.match(r"(image_\d+)", img_name)
        if base_name_match:
            base_name = base_name_match.group(1) + ".jpg"  # Desired short format
            name_mapping[img_name] = base_name

    # Rename files in the source directory
    for old_name, new_name in name_mapping.items():
        old_path = os.path.join(source_dir, old_name)
        new_path = os.path.join(source_dir, new_name)
        os.rename(old_path, new_path)

    # Filter images and update names in the JSON
    filtered_images = []
    for img in coco_data["images"]:
        if img["file_name"] in name_mapping:
            img["file_name"] = name_mapping[img["file_name"]]  # Replace with the short name
            filtered_images.append(img)

    # Get the IDs of the selected images
    selected_image_ids = {img["id"] for img in filtered_images}

    # Filter annotations related to the selected images
    filtered_annotations = [ann for ann in coco_data["annotations"] if ann["image_id"] in selected_image_ids]

    # Create the new JSON with corrected names
    filtered_coco = {
        "images": filtered_images,
        "annotations": filtered_annotations,
        "categories": coco_data["categories"]  # Keep original categories
    }

    # Save the new JSON in the same directory
    with open(output_json_path, "w") as f:
        json.dump(filtered_coco, f, indent=4)

    print(f"✅ Files renamed and new JSON saved at: {output_json_path}")

# %%
# Process all subdirectories in the source base directory
for subdir in os.listdir(source_base_dir):
    source_dir = os.path.join(source_base_dir, subdir)
    if os.path.isdir(source_dir):
        process_directory(source_dir)
# Out:
# ✅ Files renamed and new JSON saved at: ../yuvi/train/_annotations.coco.json

# %% [markdown]
# ### Process Images

# %%
# Function to crop and save images
def crop_and_save(image_path, bbox, output_path):
    image = Image.open(image_path)
    left, upper, width, height = bbox
    right = left + width
    lower = upper + height
    cropped_image = image.crop((left, upper, right, lower))
    cropped_image.save(output_path)

# Function to draw bounding boxes on the image and save it
def draw_bounding_boxes(image_path, bboxes, output_path):
    image = Image.open(image_path)
    draw = ImageDraw.Draw(image)
    for bbox in bboxes:
        left, upper, width, height = bbox
        right = left + width
        lower = upper + height
        draw.rectangle([left, upper, right, lower], outline="red", width=2)
    image.save(output_path)

# Function to process a single directory
def process_directory(source_dir):
    json_path = os.path.join(source_dir, json_file_name)
    processed_dir = os.path.join(source_dir, 'processed')
    os.makedirs(processed_dir, exist_ok=True)

    # Load annotations from the JSON file
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Create a dictionary to map image_id to file_name
    image_id_to_filename = {image['id']: image['file_name'] for image in data['images']}

    # Dictionary to group bounding boxes by image_id
    image_bboxes = {}

    # Iterate over annotations and group bounding boxes by image_id
    for annotation in data['annotations']:
        image_id = annotation['image_id']
        bbox = annotation['bbox']
        if image_id not in image_bboxes:
            image_bboxes[image_id] = []
        image_bboxes[image_id].append(bbox)

    # Iterate over images and process them
    for image_id, bboxes in image_bboxes.items():
        image_filename = image_id_to_filename[image_id]
        image_path = os.path.join(source_dir, image_filename)
        
        # Save the image with bounding boxes drawn
        output_path_with_boxes = os.path.join(processed_dir, f"{os.path.splitext(image_filename)[0]}_with_boxes.jpg")
        draw_bounding_boxes(image_path, bboxes, output_path_with_boxes)
        
        # Crop and save each bounding box individually
        for i, bbox in enumerate(bboxes):
            output_path = os.path.join(processed_dir, f"{os.path.splitext(image_filename)[0]}_crop_{i}.jpg")
            crop_and_save(image_path, bbox, output_path)
        
        print(f"Processed {image_filename} with {len(bboxes)} bounding boxes")

# %%
# Process all subdirectories in the source base directory
for subdir in os.listdir(source_base_dir):
    source_dir = os.path.join(source_base_dir, subdir)
    if os.path.isdir(source_dir):
        process_directory(source_dir)
# Out:
# Processed image_02115.jpg with 1 bounding boxes
# Processed image_00983.jpg with 1 bounding boxes
# Processed image_02814.jpg with 4 bounding boxes
# Processed image_00700.jpg with 1 bounding boxes
# Processed image_01282.jpg with 134 bounding boxes
# Processed image_07910.jpg with 1 bounding boxes
# Processed image_04030.jpg with 20 bounding boxes
# Processed image_06102.jpg with 3 bounding boxes
# Processed image_07774.jpg with 5 bounding boxes
# Processed image_07847.jpg with 30 bounding boxes
# Processed image_01063.jpg with 1 bounding boxes
# Processed image_04951.jpg with 6 bounding boxes
# Processed image_01912.jpg with 1 bounding boxes
# Processed image_04915.jpg with 7 bounding boxes
# Processed image_00052.jpg with 9 bounding boxes
# Processed image_04326.jpg with 5 bounding boxes
# Processed image_03545.jpg with 7 bounding boxes
# Processed image_00805.jpg with 1 bounding boxes
# Processed image_03531.jpg with 39 bounding boxes
# Processed image_07905.jpg with 1 bounding boxes
# Processed image_06693.jpg with 2 bounding boxes
# Processed image_06332.jpg with 14 bounding boxes
# Processed image_01027.jpg with 17 bounding boxes
# Processed image_06299.jpg with 1 bounding boxes
# Processed image_07613.jpg with 4 bounding boxes
# Processed image_04783.jpg with 2 bounding boxes
# Processed image_06355.jpg with 11 bounding boxes
# Processed image_07950.jpg with 3 bounding boxes
# Processed image_00547.jpg with 3 bounding boxes
# Processed image_03635.jpg with 11 bounding boxes
# Processed image_02366.jpg with 1 bounding boxes
# Processed image_00511.jpg with 1 bounding boxes
# Processed image_03052.jpg with 1 bounding boxes
# Processed image_01996.jpg with 3 bounding boxes
# Processed image_00754.jpg with 14 bounding boxes
# Processed image_00151.jpg with 8 bounding boxes
# Processed image_01935.jpg with 5 bounding boxes
# Processed image_03093.jpg with 58 bounding boxes
# Processed image_06996.jpg with 25 bounding boxes
# Processed image_02032.jpg with 3 bounding boxes
# Processed image_06913.jpg with 4 bounding boxes
# Processed image_03240.jpg with 8 bounding boxes
# Processed image_06298.jpg with 25 bounding boxes
# Processed image_01216.jpg with 23 bounding boxes
# Processed image_00889.jpg with 31 bounding boxes
# Processed image_00817.jpg with 6 bounding boxes
# Processed image_05249.jpg with 3 bounding boxes
# Processed image_02900.jpg with 1 bounding boxes
# Processed image_02081.jpg with 1 bounding boxes
# Processed image_05434.jpg with 1 bounding boxes
# Processed image_06928.jpg with 8 bounding boxes
# Processed image_00847.jpg with 1 bounding boxes
# Processed image_03600.jpg with 38 bounding boxes
# Processed image_01489.jpg with 4 bounding boxes
# Processed image_00308.jpg with 2 bounding boxes
# Processed image_05660.jpg with 20 bounding boxes
# Processed image_02724.jpg with 1 bounding boxes
# Processed image_05646.jpg with 1 bounding boxes
# Processed image_03850.jpg with 1 bounding boxes
# Processed image_06707.jpg with 1 bounding boxes
# Processed image_00060.jpg with 13 bounding boxes
# Processed image_04247.jpg with 19 bounding boxes
# Processed image_00506.jpg with 5 bounding boxes
# Processed image_03172.jpg with 2 bounding boxes
# Processed image_00735.jpg with 93 bounding boxes
# Processed image_00310.jpg with 5 bounding boxes
# Processed image_06894.jpg with 6 bounding boxes
# Processed image_04573.jpg with 2 bounding boxes
# Processed image_03677.jpg with 4 bounding boxes
# Processed image_01901.jpg with 5 bounding boxes
# Processed image_03139.jpg with 1 bounding boxes
# Processed image_00510.jpg with 3 bounding boxes
# Processed image_04207.jpg with 1 bounding boxes
# Processed image_01126.jpg with 2 bounding boxes
# Processed image_04718.jpg with 5 bounding boxes
# Processed image_00159.jpg with 3 bounding boxes
# Processed image_03005.jpg with 5 bounding boxes
# Processed image_00361.jpg with 2 bounding boxes
# Processed image_05234.jpg with 6 bounding boxes
# Processed image_04359.jpg with 10 bounding boxes
# Processed image_07072.jpg with 1 bounding boxes
# Processed image_06711.jpg with 1 bounding boxes
# Processed image_07310.jpg with 3 bounding boxes
# Processed image_04575.jpg with 13 bounding boxes
# Processed image_03255.jpg with 60 bounding boxes
# Processed image_00242.jpg with 8 bounding boxes
# Processed image_07217.jpg with 22 bounding boxes
# Processed image_06945.jpg with 1 bounding boxes
# Processed image_00544.jpg with 6 bounding boxes
# Processed image_00018.jpg with 1 bounding boxes
# Processed image_04406.jpg with 6 bounding boxes
# Processed image_01753.jpg with 20 bounding boxes
# Processed image_07658.jpg with 28 bounding boxes
# Processed image_02627.jpg with 5 bounding boxes
# Processed image_05067.jpg with 1 bounding boxes
# Processed image_04612.jpg with 2 bounding boxes
# Processed image_07854.jpg with 153 bounding boxes
# Processed image_02410.jpg with 7 bounding boxes
# Processed image_06538.jpg with 1 bounding boxes
# Processed image_07621.jpg with 15 bounding boxes
# Processed image_02321.jpg with 38 bounding boxes
# Processed image_01397.jpg with 1 bounding boxes
# Processed image_04001.jpg with 1 bounding boxes
# Processed image_02781.jpg with 19 bounding boxes
# Processed image_05687.jpg with 2 bounding boxes
# Processed image_02986.jpg with 8 bounding boxes
# Processed image_01432.jpg with 1 bounding boxes
# Processed image_05569.jpg with 2 bounding boxes
# Processed image_01825.jpg with 32 bounding boxes
# Processed image_07849.jpg with 7 bounding boxes
# Processed image_06836.jpg with 1 bounding boxes
# Processed image_00740.jpg with 3 bounding boxes
# Processed image_03202.jpg with 9 bounding boxes
# Processed image_04112.jpg with 4 bounding boxes
# Processed image_05515.jpg with 19 bounding boxes
# Processed image_03463.jpg with 26 bounding boxes
# Processed image_04640.jpg with 8 bounding boxes
# Processed image_02659.jpg with 27 bounding boxes
# Processed image_01201.jpg with 1 bounding boxes
# Processed image_00063.jpg with 1 bounding boxes
# Processed image_03548.jpg with 2 bounding boxes
# Processed image_06401.jpg with 3 bounding boxes
# Processed image_02514.jpg with 5 bounding boxes
# Processed image_01811.jpg with 25 bounding boxes
# Processed image_05709.jpg with 17 bounding boxes
# Processed image_06691.jpg with 18 bounding boxes
# Processed image_01172.jpg with 2 bounding boxes
# Processed image_07984.jpg with 3 bounding boxes
# Processed image_05870.jpg with 1 bounding boxes
# Processed image_00703.jpg with 7 bounding boxes
# Processed image_06851.jpg with 1 bounding boxes
# Processed image_00678.jpg with 52 bounding boxes
# Processed image_01164.jpg with 5 bounding boxes
# Processed image_00620.jpg with 4 bounding boxes
# Processed image_00328.jpg with 5 bounding boxes
# Processed image_02600.jpg with 2 bounding boxes
# Processed image_05784.jpg with 1 bounding boxes
# Processed image_00453.jpg with 4 bounding boxes
# Processed image_03233.jpg with 7 bounding boxes
# Processed image_07275.jpg with 14 bounding boxes
# Processed image_02990.jpg with 8 bounding boxes
# Processed image_06394.jpg with 13 bounding boxes
# Processed image_05267.jpg with 2 bounding boxes
# Processed image_05621.jpg with 2 bounding boxes
# Processed image_07817.jpg with 5 bounding boxes
# Processed image_03314.jpg with 1 bounding boxes
# Processed image_01415.jpg with 5 bounding boxes
# Processed image_02375.jpg with 13 bounding boxes
# Processed image_01529.jpg with 3 bounding boxes
# Processed image_05370.jpg with 3 bounding boxes
# Processed image_03001.jpg with 1 bounding boxes
# Processed image_00630.jpg with 3 bounding boxes
# Processed image_07880.jpg with 1 bounding boxes
# Processed image_00045.jpg with 1 bounding boxes
# Processed image_04279.jpg with 14 bounding boxes
# Processed image_02167.jpg with 16 bounding boxes
# Processed image_07063.jpg with 16 bounding boxes
# Processed image_06364.jpg with 2 bounding boxes
# Processed image_05953.jpg with 2 bounding boxes
# Processed image_02743.jpg with 3 bounding boxes
# Processed image_04232.jpg with 1 bounding boxes
# Processed image_01103.jpg with 4 bounding boxes
# Processed image_04337.jpg with 7 bounding boxes
# Processed image_06498.jpg with 17 bounding boxes
# Processed image_03776.jpg with 9 bounding boxes
# Processed image_03042.jpg with 5 bounding boxes
# Processed image_04424.jpg with 15 bounding boxes
# Processed image_01380.jpg with 1 bounding boxes
# Processed image_05996.jpg with 5 bounding boxes
# Processed image_03092.jpg with 30 bounding boxes
# Processed image_02388.jpg with 75 bounding boxes
# Processed image_05769.jpg with 3 bounding boxes
# Processed image_01070.jpg with 30 bounding boxes
# Processed image_04217.jpg with 8 bounding boxes
# Processed image_00215.jpg with 11 bounding boxes
# Processed image_03607.jpg with 5 bounding boxes
# Processed image_03247.jpg with 9 bounding boxes
# Processed image_05482.jpg with 3 bounding boxes
# Processed image_07899.jpg with 3 bounding boxes
# Processed image_00396.jpg with 2 bounding boxes
# Processed image_07857.jpg with 7 bounding boxes
# Processed image_02358.jpg with 3 bounding boxes
# Processed image_06039.jpg with 1 bounding boxes
# Processed image_00195.jpg with 3 bounding boxes
# Processed image_06670.jpg with 2 bounding boxes
# Processed image_02502.jpg with 9 bounding boxes
# Processed image_01139.jpg with 1 bounding boxes
# Processed image_03765.jpg with 11 bounding boxes
# Processed image_03149.jpg with 15 bounding boxes
# Processed image_06036.jpg with 8 bounding boxes
# Processed image_05799.jpg with 1 bounding boxes
# Processed image_06084.jpg with 2 bounding boxes
# Processed image_00576.jpg with 7 bounding boxes
# Processed image_00250.jpg with 8 bounding boxes
# Processed image_02216.jpg with 3 bounding boxes
# Processed image_00783.jpg with 5 bounding boxes
# Processed image_04119.jpg with 15 bounding boxes
# Processed image_05604.jpg with 1 bounding boxes
# Processed image_01444.jpg with 1 bounding boxes
# Processed image_06150.jpg with 1 bounding boxes
# Processed image_03424.jpg with 1 bounding boxes
# Processed image_00325.jpg with 2 bounding boxes
# Processed image_03910.jpg with 5 bounding boxes
# Processed image_02212.jpg with 4 bounding boxes
# Processed image_00186.jpg with 1 bounding boxes
# Processed image_05162.jpg with 7 bounding boxes
# Processed image_03298.jpg with 94 bounding boxes
# Processed image_02865.jpg with 1 bounding boxes
# Processed image_04815.jpg with 1 bounding boxes
# Processed image_07620.jpg with 1 bounding boxes
# Processed image_02179.jpg with 2 bounding boxes
# Processed image_06253.jpg with 3 bounding boxes
# Processed image_02303.jpg with 4 bounding boxes
# Processed image_06518.jpg with 3 bounding boxes
# Processed image_03011.jpg with 4 bounding boxes
# Processed image_00745.jpg with 5 bounding boxes
# Processed image_06000.jpg with 5 bounding boxes
# Processed image_02562.jpg with 1 bounding boxes
# Processed image_00574.jpg with 14 bounding boxes
# Processed image_06560.jpg with 2 bounding boxes
# Processed image_04419.jpg with 3 bounding boxes
# Processed image_01980.jpg with 3 bounding boxes
# Processed image_02980.jpg with 1 bounding boxes
# Processed image_06701.jpg with 2 bounding boxes
# Processed image_00718.jpg with 1 bounding boxes
# Processed image_01155.jpg with 11 bounding boxes
# Processed image_07127.jpg with 12 bounding boxes
# Processed image_00688.jpg with 6 bounding boxes
# Processed image_06676.jpg with 5 bounding boxes
# Processed image_01760.jpg with 8 bounding boxes
# Processed image_01314.jpg with 10 bounding boxes
# Processed image_00447.jpg with 2 bounding boxes
# Processed image_02397.jpg with 13 bounding boxes
# Processed image_05669.jpg with 15 bounding boxes
# Processed image_01267.jpg with 2 bounding boxes
# Processed image_04868.jpg with 1 bounding boxes
# Processed image_02097.jpg with 2 bounding boxes
# Processed image_05170.jpg with 20 bounding boxes
# Processed image_07189.jpg with 2 bounding boxes
# Processed image_04749.jpg with 2 bounding boxes
# Processed image_01619.jpg with 5 bounding boxes
# Processed image_04674.jpg with 1 bounding boxes
# Processed image_01579.jpg with 2 bounding boxes
# Processed image_06840.jpg with 3 bounding boxes
# Processed image_01738.jpg with 14 bounding boxes
# Processed image_06984.jpg with 3 bounding boxes
# Processed image_06082.jpg with 2 bounding boxes
# Processed image_04293.jpg with 1 bounding boxes
# Processed image_01502.jpg with 3 bounding boxes
# Processed image_06934.jpg with 34 bounding boxes
# Processed image_06792.jpg with 12 bounding boxes
# Processed image_07361.jpg with 5 bounding boxes
# Processed image_04403.jpg with 3 bounding boxes
# Processed image_05470.jpg with 16 bounding boxes
# Processed image_02041.jpg with 6 bounding boxes
# Processed image_06615.jpg with 1 bounding boxes
# Processed image_01327.jpg with 6 bounding boxes
# Processed image_00268.jpg with 2 bounding boxes
# Processed image_03459.jpg with 14 bounding boxes
# Processed image_05145.jpg with 8 bounding boxes
# Processed image_05954.jpg with 36 bounding boxes
# Processed image_03178.jpg with 6 bounding boxes
# Processed image_05582.jpg with 9 bounding boxes
# Processed image_03869.jpg with 19 bounding boxes
# Processed image_02576.jpg with 1 bounding boxes
# Processed image_05835.jpg with 1 bounding boxes
# Processed image_05216.jpg with 22 bounding boxes
# Processed image_07937.jpg with 2 bounding boxes
# Processed image_02686.jpg with 26 bounding boxes
# Processed image_05682.jpg with 17 bounding boxes
# Processed image_00855.jpg with 1 bounding boxes
# Processed image_02992.jpg with 1 bounding boxes
# Processed image_03153.jpg with 1 bounding boxes
# Processed image_07852.jpg with 7 bounding boxes
# Processed image_02124.jpg with 2 bounding boxes
# Processed image_00109.jpg with 12 bounding boxes
# Processed image_02618.jpg with 2 bounding boxes
# Processed image_07182.jpg with 2 bounding boxes
# Processed image_06548.jpg with 1 bounding boxes
# Processed image_04068.jpg with 7 bounding boxes
# Processed image_02110.jpg with 3 bounding boxes
# Processed image_01750.jpg with 6 bounding boxes
# Processed image_01374.jpg with 1 bounding boxes
# Processed image_01055.jpg with 2 bounding boxes
# Processed image_02007.jpg with 4 bounding boxes
# Processed image_04600.jpg with 40 bounding boxes
# Processed image_06555.jpg with 1 bounding boxes
# Processed image_03912.jpg with 13 bounding boxes
# Processed image_02701.jpg with 1 bounding boxes
# Processed image_06393.jpg with 1 bounding boxes
# Processed image_07145.jpg with 14 bounding boxes
# Processed image_03220.jpg with 7 bounding boxes
# Processed image_05492.jpg with 4 bounding boxes
# Processed image_03103.jpg with 8 bounding boxes
# Processed image_07587.jpg with 1 bounding boxes
# Processed image_03769.jpg with 2 bounding boxes
# Processed image_06033.jpg with 4 bounding boxes
# Processed image_02357.jpg with 2 bounding boxes
# Processed image_03154.jpg with 11 bounding boxes
# Processed image_00704.jpg with 2 bounding boxes
# Processed image_04288.jpg with 20 bounding boxes
# Processed image_07089.jpg with 6 bounding boxes
# Processed image_04146.jpg with 2 bounding boxes
# Processed image_01544.jpg with 3 bounding boxes
# Processed image_04678.jpg with 6 bounding boxes
# Processed image_00478.jpg with 2 bounding boxes
# Processed image_03969.jpg with 38 bounding boxes
# Processed image_01038.jpg with 6 bounding boxes
# Processed image_04086.jpg with 1 bounding boxes
# Processed image_01842.jpg with 4 bounding boxes
# Processed image_02188.jpg with 1 bounding boxes
# Processed image_06305.jpg with 7 bounding boxes
# Processed image_04552.jpg with 2 bounding boxes
# Processed image_00086.jpg with 6 bounding boxes
# Processed image_03158.jpg with 3 bounding boxes
# Processed image_04387.jpg with 4 bounding boxes
# Processed image_01338.jpg with 4 bounding boxes
# Processed image_04329.jpg with 2 bounding boxes
# Processed image_02902.jpg with 4 bounding boxes
# Processed image_04905.jpg with 1 bounding boxes
# Processed image_02833.jpg with 2 bounding boxes
# Processed image_06959.jpg with 227 bounding boxes
# Processed image_00080.jpg with 3 bounding boxes
# Processed image_00696.jpg with 5 bounding boxes
# Processed image_00017.jpg with 4 bounding boxes
# Processed image_07383.jpg with 5 bounding boxes
# Processed image_03438.jpg with 6 bounding boxes
# Processed image_00248.jpg with 13 bounding boxes
# Processed image_06647.jpg with 6 bounding boxes
# Processed image_07815.jpg with 3 bounding boxes
# Processed image_04236.jpg with 1 bounding boxes
# Processed image_00078.jpg with 1 bounding boxes
# Processed image_03575.jpg with 7 bounding boxes
# Processed image_00170.jpg with 5 bounding boxes
# Processed image_07710.jpg with 4 bounding boxes
# Processed image_03786.jpg with 1 bounding boxes
# Processed image_07234.jpg with 11 bounding boxes
# Processed image_01163.jpg with 1 bounding boxes
# Processed image_05464.jpg with 14 bounding boxes
# Processed image_03035.jpg with 4 bounding boxes
# Processed image_02764.jpg with 3 bounding boxes
# Processed image_07136.jpg with 7 bounding boxes
# Processed image_06124.jpg with 1 bounding boxes
# Processed image_03951.jpg with 3 bounding boxes
# Processed image_01952.jpg with 2 bounding boxes
# Processed image_02351.jpg with 3 bounding boxes
# Processed image_01926.jpg with 3 bounding boxes
# Processed image_00897.jpg with 2 bounding boxes
# Processed image_04731.jpg with 13 bounding boxes
# Processed image_01035.jpg with 4 bounding boxes
# Processed image_00221.jpg with 12 bounding boxes
# Processed image_05423.jpg with 9 bounding boxes
# Processed image_02242.jpg with 13 bounding boxes
# Processed image_05062.jpg with 5 bounding boxes
# Processed image_01576.jpg with 18 bounding boxes
# Processed image_06312.jpg with 2 bounding boxes
# Processed image_04100.jpg with 4 bounding boxes
# Processed image_01834.jpg with 5 bounding boxes
# Processed image_01442.jpg with 1 bounding boxes
# Processed image_07995.jpg with 2 bounding boxes
# Processed image_03349.jpg with 10 bounding boxes
# Processed image_03882.jpg with 6 bounding boxes
# Processed image_05280.jpg with 6 bounding boxes
# Processed image_00225.jpg with 3 bounding boxes
# Processed image_01930.jpg with 1 bounding boxes
# Processed image_04353.jpg with 4 bounding boxes
# Processed image_06339.jpg with 10 bounding boxes
# Processed image_04301.jpg with 4 bounding boxes
# Processed image_04744.jpg with 8 bounding boxes
# Processed image_01219.jpg with 17 bounding boxes
# Processed image_03785.jpg with 2 bounding boxes
# Processed image_00828.jpg with 2 bounding boxes
# Processed image_02463.jpg with 1 bounding boxes
# Processed image_01616.jpg with 3 bounding boxes
# Processed image_04469.jpg with 65 bounding boxes
# Processed image_04644.jpg with 4 bounding boxes
# Processed image_03435.jpg with 10 bounding boxes
# Processed image_04033.jpg with 9 bounding boxes
# Processed image_08025.jpg with 17 bounding boxes
# Processed image_06980.jpg with 2 bounding boxes
# Processed image_00780.jpg with 30 bounding boxes
# Processed image_05750.jpg with 2 bounding boxes
# Processed image_02991.jpg with 2 bounding boxes
# Processed image_00650.jpg with 43 bounding boxes
# Processed image_07570.jpg with 9 bounding boxes
# Processed image_00435.jpg with 1 bounding boxes
# Processed image_03405.jpg with 10 bounding boxes
# Processed image_03934.jpg with 1 bounding boxes
# Processed image_06973.jpg with 2 bounding boxes
# Processed image_00470.jpg with 7 bounding boxes
# Processed image_07373.jpg with 1 bounding boxes
# Processed image_07390.jpg with 3 bounding boxes
# Processed image_02688.jpg with 1 bounding boxes
# Processed image_04642.jpg with 4 bounding boxes
# Processed image_05543.jpg with 15 bounding boxes
# Processed image_05178.jpg with 3 bounding boxes
# Processed image_06637.jpg with 2 bounding boxes
# Processed image_04228.jpg with 13 bounding boxes
# Processed image_00216.jpg with 6 bounding boxes
# Processed image_06176.jpg with 11 bounding boxes
# Processed image_00351.jpg with 33 bounding boxes
# Processed image_00388.jpg with 2 bounding boxes
# Processed image_06504.jpg with 12 bounding boxes
# Processed image_05571.jpg with 3 bounding boxes
# Processed image_07503.jpg with 4 bounding boxes
# Processed image_02104.jpg with 10 bounding boxes
# Processed image_00808.jpg with 1 bounding boxes
# Processed image_05636.jpg with 6 bounding boxes
# Processed image_07652.jpg with 52 bounding boxes
# Processed image_02051.jpg with 13 bounding boxes
# Processed image_06184.jpg with 1 bounding boxes
# Processed image_00419.jpg with 7 bounding boxes
# Processed image_06424.jpg with 55 bounding boxes
# Processed image_06865.jpg with 12 bounding boxes
# Processed image_01417.jpg with 35 bounding boxes
# Processed image_01582.jpg with 2 bounding boxes
# Processed image_07561.jpg with 22 bounding boxes
# Processed image_03440.jpg with 7 bounding boxes
# Processed image_00643.jpg with 12 bounding boxes
# Processed image_05873.jpg with 2 bounding boxes
# Processed image_06509.jpg with 1 bounding boxes
# Processed image_01966.jpg with 16 bounding boxes
# Processed image_05837.jpg with 85 bounding boxes
# Processed image_07279.jpg with 28 bounding boxes
# Processed image_02561.jpg with 8 bounding boxes
# Processed image_00502.jpg with 1 bounding boxes
# Processed image_00748.jpg with 21 bounding boxes
# Processed image_02825.jpg with 6 bounding boxes
# Processed image_07038.jpg with 1 bounding boxes
# Processed image_07691.jpg with 26 bounding boxes
# Processed image_04183.jpg with 2 bounding boxes
# Processed image_05359.jpg with 25 bounding boxes
# Processed image_06529.jpg with 2 bounding boxes
# Processed image_07585.jpg with 11 bounding boxes
# Processed image_04771.jpg with 1 bounding boxes
# Processed image_00809.jpg with 3 bounding boxes
# Processed image_00609.jpg with 1 bounding boxes
# Processed image_00003.jpg with 83 bounding boxes
# Processed image_03090.jpg with 15 bounding boxes
# Processed image_02184.jpg with 1 bounding boxes
# Processed image_05363.jpg with 2 bounding boxes
# Processed image_00129.jpg with 36 bounding boxes
# Processed image_03932.jpg with 15 bounding boxes
# Processed image_04164.jpg with 8 bounding boxes
# Processed image_05119.jpg with 9 bounding boxes
# Processed image_05729.jpg with 3 bounding boxes
# Processed image_07780.jpg with 10 bounding boxes
# Processed image_07531.jpg with 7 bounding boxes
# Processed image_05046.jpg with 2 bounding boxes
# Processed image_02131.jpg with 12 bounding boxes
# Processed image_03372.jpg with 4 bounding boxes
# Processed image_03891.jpg with 14 bounding boxes
# Processed image_06949.jpg with 1 bounding boxes
# Processed image_06071.jpg with 7 bounding boxes
# Processed image_00698.jpg with 13 bounding boxes
# Processed image_07370.jpg with 2 bounding boxes
# Processed image_04726.jpg with 2 bounding boxes
# Processed image_06476.jpg with 1 bounding boxes
# Processed image_06304.jpg with 4 bounding boxes
# Processed image_05024.jpg with 1 bounding boxes
# Processed image_03343.jpg with 42 bounding boxes
# Processed image_07414.jpg with 6 bounding boxes
# Processed image_05126.jpg with 8 bounding boxes
# Processed image_01076.jpg with 2 bounding boxes
# Processed image_04609.jpg with 2 bounding boxes
# Processed image_06939.jpg with 18 bounding boxes
# Processed image_00274.jpg with 3 bounding boxes
# Processed image_00399.jpg with 2 bounding boxes
# Processed image_00164.jpg with 2 bounding boxes
# Processed image_03352.jpg with 10 bounding boxes
# Processed image_01702.jpg with 11 bounding boxes
# Processed image_00139.jpg with 8 bounding boxes
# Processed image_03709.jpg with 2 bounding boxes
# Processed image_04412.jpg with 5 bounding boxes
# Processed image_01004.jpg with 1 bounding boxes
# Processed image_07026.jpg with 7 bounding boxes
# Processed image_06320.jpg with 26 bounding boxes
# Processed image_07389.jpg with 1 bounding boxes
# Processed image_06978.jpg with 18 bounding boxes
# Processed image_02471.jpg with 2 bounding boxes
# Processed image_00366.jpg with 1 bounding boxes
# Processed image_07478.jpg with 1 bounding boxes
# Processed image_05158.jpg with 2 bounding boxes
# Processed image_02000.jpg with 22 bounding boxes
# Processed image_03715.jpg with 17 bounding boxes
# Processed image_06205.jpg with 5 bounding boxes
# Processed image_07210.jpg with 20 bounding boxes
# Processed image_05768.jpg with 4 bounding boxes
# Processed image_00372.jpg with 5 bounding boxes
# Processed image_01125.jpg with 20 bounding boxes
# Processed image_06839.jpg with 1 bounding boxes
# Processed image_05286.jpg with 17 bounding boxes
# Processed image_00740.jpg with 6 bounding boxes
# Processed image_07007.jpg with 11 bounding boxes
# Processed image_00664.jpg with 9 bounding boxes
# Processed image_05959.jpg with 10 bounding boxes
# Processed image_06612.jpg with 17 bounding boxes
# Processed image_00249.jpg with 10 bounding boxes
# Processed image_02163.jpg with 2 bounding boxes
# Processed image_01404.jpg with 3 bounding boxes
# Processed image_05277.jpg with 1 bounding boxes
# Processed image_03994.jpg with 4 bounding boxes
# Processed image_07981.jpg with 4 bounding boxes
# Processed image_04323.jpg with 9 bounding boxes
# Processed image_00322.jpg with 4 bounding boxes
# Processed image_03014.jpg with 3 bounding boxes
# Processed image_03086.jpg with 15 bounding boxes
# Processed image_03518.jpg with 2 bounding boxes
# Processed image_06367.jpg with 2 bounding boxes
# Processed image_02699.jpg with 4 bounding boxes
# Processed image_05737.jpg with 5 bounding boxes
# Processed image_06539.jpg with 4 bounding boxes
# Processed image_03379.jpg with 3 bounding boxes
# Processed image_06438.jpg with 4 bounding boxes
# Processed image_05123.jpg with 1 bounding boxes
# Processed image_06310.jpg with 4 bounding boxes
# Processed image_00545.jpg with 10 bounding boxes
# Processed image_05559.jpg with 16 bounding boxes
# Processed image_04029.jpg with 2 bounding boxes
# Processed image_02605.jpg with 8 bounding boxes
# Processed image_02813.jpg with 4 bounding boxes
# Processed image_02251.jpg with 10 bounding boxes
# Processed image_07462.jpg with 3 bounding boxes
# Processed image_05310.jpg with 2 bounding boxes
# Processed image_04629.jpg with 3 bounding boxes
# Processed image_00187.jpg with 2 bounding boxes
# Processed image_01826.jpg with 3 bounding boxes
# Processed image_02703.jpg with 2 bounding boxes
# Processed image_06089.jpg with 1 bounding boxes
# Processed image_06588.jpg with 7 bounding boxes
# Processed image_00857.jpg with 9 bounding boxes
# Processed image_02863.jpg with 6 bounding boxes
# Processed image_02359.jpg with 1 bounding boxes
# Processed image_05238.jpg with 28 bounding boxes
# Processed image_02270.jpg with 12 bounding boxes
# Processed image_02597.jpg with 3 bounding boxes
# Processed image_05845.jpg with 1 bounding boxes
# Processed image_01493.jpg with 4 bounding boxes
# Processed image_06152.jpg with 2 bounding boxes
# Processed image_03211.jpg with 22 bounding boxes
# Processed image_05157.jpg with 1 bounding boxes
# Processed image_07761.jpg with 7 bounding boxes
# Processed image_06578.jpg with 19 bounding boxes
# Processed image_07023.jpg with 12 bounding boxes
# Processed image_05602.jpg with 4 bounding boxes
# Processed image_05817.jpg with 14 bounding boxes
# Processed image_06919.jpg with 3 bounding boxes
# Processed image_06051.jpg with 18 bounding boxes
# Processed image_02853.jpg with 3 bounding boxes
# Processed image_05016.jpg with 1 bounding boxes
# Processed image_03820.jpg with 25 bounding boxes
# Processed image_03884.jpg with 3 bounding boxes
# Processed image_01910.jpg with 1 bounding boxes
# Processed image_07290.jpg with 4 bounding boxes
# Processed image_06744.jpg with 99 bounding boxes
# Processed image_06391.jpg with 4 bounding boxes
# Processed image_00816.jpg with 1 bounding boxes
# Processed image_04128.jpg with 43 bounding boxes
# Processed image_07895.jpg with 6 bounding boxes
# Processed image_00975.jpg with 6 bounding boxes
# Processed image_00803.jpg with 3 bounding boxes
# Processed image_07024.jpg with 3 bounding boxes
# Processed image_00031.jpg with 5 bounding boxes
# Processed image_00315.jpg with 4 bounding boxes
# Processed image_07343.jpg with 3 bounding boxes
# Processed image_03807.jpg with 3 bounding boxes
# Processed image_02035.jpg with 3 bounding boxes
# Processed image_00438.jpg with 37 bounding boxes
# Processed image_01514.jpg with 6 bounding boxes
# Processed image_06631.jpg with 3 bounding boxes
# Processed image_04805.jpg with 3 bounding boxes
# Processed image_02851.jpg with 10 bounding boxes
# Processed image_03470.jpg with 7 bounding boxes
# Processed image_07737.jpg with 2 bounding boxes
# Processed image_00069.jpg with 1 bounding boxes
# Processed image_06882.jpg with 6 bounding boxes
# Processed image_02433.jpg with 4 bounding boxes
# Processed image_01490.jpg with 4 bounding boxes
# Processed image_04799.jpg with 3 bounding boxes
# Processed image_06186.jpg with 6 bounding boxes
# Processed image_04586.jpg with 1 bounding boxes
# Processed image_07946.jpg with 1 bounding boxes
# Processed image_01929.jpg with 8 bounding boxes
# Processed image_04820.jpg with 1 bounding boxes
# Processed image_00167.jpg with 4 bounding boxes
# Processed image_04754.jpg with 3 bounding boxes
# Processed image_02113.jpg with 2 bounding boxes
# Processed image_00275.jpg with 49 bounding boxes
# Processed image_04649.jpg with 30 bounding boxes
# Processed image_07416.jpg with 3 bounding boxes
# Processed image_00330.jpg with 2 bounding boxes
# Processed image_01809.jpg with 6 bounding boxes
# Processed image_05439.jpg with 5 bounding boxes
# Processed image_00399.jpg with 23 bounding boxes
# Processed image_02624.jpg with 2 bounding boxes
# Processed image_04515.jpg with 1 bounding boxes
# Processed image_01965.jpg with 6 bounding boxes
# Processed image_07940.jpg with 2 bounding boxes
# Processed image_05059.jpg with 6 bounding boxes
# Processed image_03294.jpg with 1 bounding boxes
# Processed image_00784.jpg with 4 bounding boxes
# Processed image_06050.jpg with 5 bounding boxes
# Processed image_02955.jpg with 37 bounding boxes
# Processed image_03961.jpg with 5 bounding boxes
# Processed image_04093.jpg with 9 bounding boxes
# Processed image_06155.jpg with 2 bounding boxes
# Processed image_05357.jpg with 1 bounding boxes
# Processed image_07964.jpg with 3 bounding boxes
# Processed image_00728.jpg with 31 bounding boxes
# Processed image_03529.jpg with 3 bounding boxes
# Processed image_02183.jpg with 1 bounding boxes
# Processed image_01902.jpg with 22 bounding boxes
# Processed image_06652.jpg with 7 bounding boxes
# Processed image_00311.jpg with 4 bounding boxes
# Processed image_07099.jpg with 2 bounding boxes
# Processed image_05731.jpg with 9 bounding boxes
# Processed image_03695.jpg with 45 bounding boxes
# Processed image_03561.jpg with 6 bounding boxes
# Processed image_00184.jpg with 7 bounding boxes
# Processed image_00397.jpg with 4 bounding boxes
# Processed image_04266.jpg with 1 bounding boxes
# Processed image_05860.jpg with 11 bounding boxes
# Processed image_02450.jpg with 5 bounding boxes
# Processed image_06573.jpg with 1 bounding boxes
# Processed image_00298.jpg with 4 bounding boxes
# Processed image_00114.jpg with 7 bounding boxes
# Processed image_07877.jpg with 20 bounding boxes
# Processed image_02235.jpg with 3 bounding boxes
# Processed image_05401.jpg with 5 bounding boxes
# Processed image_06185.jpg with 13 bounding boxes
# Processed image_02267.jpg with 19 bounding boxes
# Processed image_01548.jpg with 10 bounding boxes
# Processed image_03452.jpg with 17 bounding boxes
# Processed image_04423.jpg with 33 bounding boxes
# Processed image_03449.jpg with 9 bounding boxes
# Processed image_05240.jpg with 2 bounding boxes
# Processed image_03758.jpg with 13 bounding boxes
# Processed image_04957.jpg with 2 bounding boxes
# Processed image_05776.jpg with 51 bounding boxes
# Processed image_03175.jpg with 15 bounding boxes
# Processed image_00205.jpg with 1 bounding boxes
# Processed image_06867.jpg with 26 bounding boxes
# Processed image_00902.jpg with 10 bounding boxes
# Processed image_07903.jpg with 9 bounding boxes
# Processed image_03398.jpg with 7 bounding boxes
# Processed image_07375.jpg with 1 bounding boxes
# Processed image_00349.jpg with 2 bounding boxes
# Processed image_06293.jpg with 3 bounding boxes
# Processed image_07085.jpg with 3 bounding boxes
# Processed image_03667.jpg with 1 bounding boxes
# Processed image_03291.jpg with 1 bounding boxes
# Processed image_01626.jpg with 3 bounding boxes
# Processed image_07776.jpg with 3 bounding boxes
# Processed image_07971.jpg with 7 bounding boxes
# Processed image_02899.jpg with 23 bounding boxes
# Processed image_05994.jpg with 1 bounding boxes
# Processed image_00830.jpg with 1 bounding boxes
# Processed image_03051.jpg with 6 bounding boxes
# Processed image_02470.jpg with 11 bounding boxes
# Processed image_04593.jpg with 9 bounding boxes
# Processed image_00040.jpg with 3 bounding boxes
# Processed image_00395.jpg with 16 bounding boxes
# Processed image_05957.jpg with 8 bounding boxes
# Processed image_06765.jpg with 1 bounding boxes
# Processed image_04395.jpg with 2 bounding boxes
# Processed image_02817.jpg with 4 bounding boxes
# Processed image_06512.jpg with 5 bounding boxes
# Processed image_05260.jpg with 1 bounding boxes
# Processed image_05865.jpg with 4 bounding boxes
# Processed image_06710.jpg with 1 bounding boxes
# Processed image_01151.jpg with 2 bounding boxes
# Processed image_06802.jpg with 56 bounding boxes
# Processed image_03020.jpg with 4 bounding boxes
# Processed image_03748.jpg with 1 bounding boxes
# Processed image_04311.jpg with 3 bounding boxes
# Processed image_01350.jpg with 28 bounding boxes
# Processed image_02347.jpg with 2 bounding boxes
# Processed image_02506.jpg with 2 bounding boxes
# Processed image_07626.jpg with 8 bounding boxes
# Processed image_06221.jpg with 14 bounding boxes
# Processed image_06446.jpg with 37 bounding boxes
# Processed image_02786.jpg with 7 bounding boxes
# Processed image_04319.jpg with 78 bounding boxes
# Processed image_00341.jpg with 2 bounding boxes
# Processed image_00279.jpg with 1 bounding boxes
# Processed image_00369.jpg with 17 bounding boxes
# Processed image_04205.jpg with 7 bounding boxes
# Processed image_02566.jpg with 22 bounding boxes
# Processed image_03239.jpg with 77 bounding boxes
# Processed image_03975.jpg with 37 bounding boxes
# Processed image_03414.jpg with 16 bounding boxes
# Processed image_07731.jpg with 12 bounding boxes
# Processed image_05530.jpg with 5 bounding boxes
# Processed image_01895.jpg with 6 bounding boxes
# Processed image_04635.jpg with 5 bounding boxes
# Processed image_00929.jpg with 29 bounding boxes
# Processed image_06385.jpg with 6 bounding boxes
# Processed image_06821.jpg with 9 bounding boxes
# Processed image_00867.jpg with 2 bounding boxes
# Processed image_02045.jpg with 3 bounding boxes
# Processed image_02626.jpg with 34 bounding boxes
# Processed image_07647.jpg with 2 bounding boxes
# Processed image_04661.jpg with 3 bounding boxes
# Processed image_00219.jpg with 2 bounding boxes
# Processed image_00974.jpg with 5 bounding boxes
# Processed image_06622.jpg with 16 bounding boxes
# Processed image_06174.jpg with 1 bounding boxes
# Processed image_04702.jpg with 16 bounding boxes
# Processed image_04597.jpg with 3 bounding boxes
# Processed image_07948.jpg with 7 bounding boxes
# Processed image_02591.jpg with 32 bounding boxes
# Processed image_03079.jpg with 6 bounding boxes
# Processed image_07804.jpg with 9 bounding boxes
# Processed image_02871.jpg with 5 bounding boxes
# Processed image_00726.jpg with 3 bounding boxes
# Processed image_00589.jpg with 3 bounding boxes
# Processed image_03707.jpg with 1 bounding boxes
# Processed image_08014.jpg with 3 bounding boxes
# Processed image_01864.jpg with 6 bounding boxes
# Processed image_00823.jpg with 4 bounding boxes
# Processed image_03745.jpg with 2 bounding boxes
# Processed image_02912.jpg with 34 bounding boxes
# Processed image_00125.jpg with 4 bounding boxes
# Processed image_02685.jpg with 3 bounding boxes
# Processed image_03665.jpg with 7 bounding boxes
# Processed image_00043.jpg with 1 bounding boxes
# Processed image_00474.jpg with 5 bounding boxes
# Processed image_03656.jpg with 5 bounding boxes
# Processed image_01294.jpg with 15 bounding boxes
# Processed image_03991.jpg with 3 bounding boxes
# Processed image_04111.jpg with 11 bounding boxes
# Processed image_04544.jpg with 8 bounding boxes
# Processed image_04202.jpg with 11 bounding boxes
# Processed image_03489.jpg with 4 bounding boxes
# Processed image_03045.jpg with 1 bounding boxes
# Processed image_02268.jpg with 1 bounding boxes
# Processed image_03921.jpg with 2 bounding boxes
# Processed image_03002.jpg with 26 bounding boxes
# Processed image_04699.jpg with 2 bounding boxes
# Processed image_01326.jpg with 1 bounding boxes
# Processed image_02072.jpg with 6 bounding boxes
# Processed image_05820.jpg with 3 bounding boxes
# Processed image_00727.jpg with 2 bounding boxes
# Processed image_02205.jpg with 1 bounding boxes
# Processed image_05291.jpg with 7 bounding boxes
# Processed image_01202.jpg with 1 bounding boxes
# Processed image_06524.jpg with 9 bounding boxes
# Processed image_01669.jpg with 1 bounding boxes
# Processed image_05484.jpg with 6 bounding boxes
# Processed image_01258.jpg with 6 bounding boxes
# Processed image_04362.jpg with 2 bounding boxes
# Processed image_03895.jpg with 2 bounding boxes
# Processed image_01723.jpg with 11 bounding boxes
# Processed image_01778.jpg with 2 bounding boxes
# Processed image_07515.jpg with 11 bounding boxes
# Processed image_04810.jpg with 6 bounding boxes
# Processed image_05762.jpg with 1 bounding boxes
# Processed image_03553.jpg with 5 bounding boxes
# Processed image_06238.jpg with 3 bounding boxes
# Processed image_03602.jpg with 13 bounding boxes
# Processed image_07818.jpg with 7 bounding boxes
# Processed image_00741.jpg with 15 bounding boxes
# Processed image_00297.jpg with 17 bounding boxes
# Processed image_05398.jpg with 1 bounding boxes
# Processed image_04636.jpg with 2 bounding boxes
# Processed image_04767.jpg with 10 bounding boxes
# Processed image_07953.jpg with 2 bounding boxes
# Processed image_00359.jpg with 3 bounding boxes
# Processed image_04027.jpg with 1 bounding boxes
# Processed image_00758.jpg with 4 bounding boxes
# Processed image_04263.jpg with 4 bounding boxes
# Processed image_07816.jpg with 7 bounding boxes
# Processed image_02995.jpg with 6 bounding boxes
# Processed image_06610.jpg with 2 bounding boxes
# Processed image_00967.jpg with 3 bounding boxes
# Processed image_01528.jpg with 31 bounding boxes
# Processed image_06248.jpg with 2 bounding boxes
# Processed image_03971.jpg with 2 bounding boxes
# Processed image_06871.jpg with 46 bounding boxes
# Processed image_02653.jpg with 4 bounding boxes
# Processed image_06858.jpg with 1 bounding boxes
# Processed image_03651.jpg with 2 bounding boxes
# Processed image_07972.jpg with 8 bounding boxes
# Processed image_04909.jpg with 30 bounding boxes
# Processed image_05783.jpg with 3 bounding boxes
# Processed image_00406.jpg with 19 bounding boxes
# Processed image_02749.jpg with 1 bounding boxes
# Processed image_05618.jpg with 4 bounding boxes
# Processed image_05770.jpg with 6 bounding boxes
# Processed image_00162.jpg with 7 bounding boxes
# Processed image_05139.jpg with 2 bounding boxes
# Processed image_01846.jpg with 5 bounding boxes
# Processed image_03963.jpg with 7 bounding boxes
# Processed image_06579.jpg with 1 bounding boxes
# Processed image_01113.jpg with 1 bounding boxes
# Processed image_04251.jpg with 1 bounding boxes
# Processed image_01850.jpg with 14 bounding boxes
# Processed image_01871.jpg with 2 bounding boxes
# Processed image_06737.jpg with 2 bounding boxes
# Processed image_06937.jpg with 4 bounding boxes
# Processed image_05025.jpg with 2 bounding boxes
# Processed image_05719.jpg with 1 bounding boxes
# Processed image_01860.jpg with 13 bounding boxes
# Processed image_03516.jpg with 19 bounding boxes
# Processed image_06159.jpg with 10 bounding boxes
# Processed image_01109.jpg with 6 bounding boxes
# Processed image_04180.jpg with 2 bounding boxes
# Processed image_04241.jpg with 1 bounding boxes
# Processed image_07789.jpg with 5 bounding boxes
# Processed image_01543.jpg with 25 bounding boxes
# Processed image_06841.jpg with 1 bounding boxes
# Processed image_00067.jpg with 2 bounding boxes
# Processed image_04211.jpg with 42 bounding boxes
# Processed image_05441.jpg with 53 bounding boxes
# Processed image_07513.jpg with 1 bounding boxes
# Processed image_06697.jpg with 3 bounding boxes
# Processed image_02307.jpg with 3 bounding boxes
# Processed image_06533.jpg with 1 bounding boxes
# Processed image_01613.jpg with 1 bounding boxes
# Processed image_02959.jpg with 10 bounding boxes
# Processed image_02929.jpg with 2 bounding boxes
# Processed image_04039.jpg with 3 bounding boxes
# Processed image_05695.jpg with 2 bounding boxes
# Processed image_05611.jpg with 1 bounding boxes
# Processed image_03101.jpg with 3 bounding boxes
# Processed image_02695.jpg with 1 bounding boxes
# Processed image_00829.jpg with 4 bounding boxes
# Processed image_04818.jpg with 4 bounding boxes
# Processed image_07362.jpg with 3 bounding boxes
# Processed image_03416.jpg with 2 bounding boxes
# Processed image_04246.jpg with 3 bounding boxes
# Processed image_00674.jpg with 1 bounding boxes
# Processed image_05931.jpg with 1 bounding boxes
# Processed image_00079.jpg with 31 bounding boxes
# Processed image_00523.jpg with 1 bounding boxes
# Processed image_06880.jpg with 2 bounding boxes
# Processed image_03010.jpg with 1 bounding boxes
# Processed image_03370.jpg with 10 bounding boxes
# Processed image_01373.jpg with 3 bounding boxes
# Processed image_06757.jpg with 7 bounding boxes
# Processed image_00920.jpg with 16 bounding boxes
# Processed image_01039.jpg with 4 bounding boxes
# Processed image_05585.jpg with 12 bounding boxes
# Processed image_07432.jpg with 2 bounding boxes
# Processed image_01783.jpg with 8 bounding boxes
# Processed image_05402.jpg with 40 bounding boxes
# Processed image_04175.jpg with 9 bounding boxes
# Processed image_04079.jpg with 2 bounding boxes
# Processed image_03620.jpg with 1 bounding boxes
# Processed image_00251.jpg with 6 bounding boxes
# Processed image_02532.jpg with 3 bounding boxes
# Processed image_06634.jpg with 1 bounding boxes
# Processed image_04521.jpg with 5 bounding boxes
# Processed image_07160.jpg with 8 bounding boxes
# Processed image_03890.jpg with 9 bounding boxes
# Processed image_04255.jpg with 1 bounding boxes
# Processed image_05596.jpg with 1 bounding boxes
# Processed image_07717.jpg with 37 bounding boxes
# Processed image_02997.jpg with 7 bounding boxes
# Processed image_06719.jpg with 9 bounding boxes
# Processed image_01522.jpg with 1 bounding boxes
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3 source_dir = os.path.join(source_base_dir, subdir)
#       4 if os.path.isdir(source_dir):
# ----> 5     process_directory(source_dir)
#
# Cell In[11], line 57, in process_directory(source_dir)
#      55 for i, bbox in enumerate(bboxes):
#      56     output_path = os.path.join(processed_dir, f"{os.path.splitext(image_filename)[0]}_crop_{i}.jpg")
# ---> 57     crop_and_save(image_path, bbox, output_path)
#      59 print(f"Processed {image_filename} with {len(bboxes)} bounding boxes")
#
# Cell In[11], line 8, in crop_and_save(image_path, bbox, output_path)
#       6 lower = upper + height
#       7 cropped_image = image.crop((left, upper, right, lower))
# ----> 8 cropped_image.save(output_path)
#
# File ~/Library/CloudStorage/OneDrive-Personal/estudio/Harvard/Classes/CSCI 599A/Code/CSCI_E-599a/.venv/lib/python3.12/site-packages/PIL/Image.py:2596, in Image.save(self, fp, format, **params)
#    2593     fp = cast(IO[bytes], fp)
#    2595 try:
# -> 2596     save_handler(self, fp, filename)
#    2597 except Exception:
#    2598     if open_fp:
#
# File ~/Library/CloudStorage/OneDrive-Personal/estudio/Harvard/Classes/CSCI 599A/Code/CSCI_E-599a/.venv/lib/python3.12/site-packages/PIL/JpegImagePlugin.py:662, in _save(im, fp, filename)
#     660 if im.width == 0 or im.height == 0:
#     661     msg = "cannot write empty image as JPEG"
# --> 662     raise ValueError(msg)
#     664 try:
#     665     rawmode = RAWMODE[im.mode]
#
# ValueError: cannot write empty image as JPEG
